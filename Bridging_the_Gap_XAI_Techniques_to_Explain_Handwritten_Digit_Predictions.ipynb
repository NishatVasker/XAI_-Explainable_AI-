# %% [markdown]
# <a href="https://colab.research.google.com/github/NishatVasker/XAI_-Explainable_AI-/blob/main/Bridging_the_Gap_XAI_Techniques_to_Explain_Handwritten_Digit_Predictions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.2.0
# !pip install aix360
# !pip install shap

# %%
# !pip install tensorflow==2.2.0
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.2.0 (from versions: 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0, 2.11.1, 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.15.0rc0, 2.15.0rc1)
# ERROR: No matching distribution found for tensorflow==2.2.0

# %%
pip install tensorflow

# %%
# !pip install tensorflow==2.14.0
import tensorflow as tf
print(tf.__version__)

# %%
# !pip install tensorflow==2.14.0

# %%
def to_rgb(x):
    x_rgb = np.zeros((x.shape[0], 28, 28, 3))
    for i in range(3):
        x_rgb[...,i] = x[..., 0]
    return x_rgb

# %%
# !pip install mnist

# %%
import tensorflow as tf
import mnist
import numpy as np

# Model / data parameters
num_classes = 10
input_shape = (28, 28, 3)

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")

x_train = to_rgb(x_train)
x_test = to_rgb(x_test)

# convert class vectors to binary class matrices
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)
# Out:
# ...
# 11490434/11490434 [==============================] - 1s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
import tensorflow as tf
import mnist
import numpy as np

# Model / data parameters
num_classes = 10
input_shape = (28, 28, 3)

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

# Convert grayscale images to RGB format by replicating the single channel
x_train = np.tile(x_train, (1, 1, 1, 3))
x_test = np.tile(x_test, (1, 1, 1, 3))

print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")

# convert class vectors to binary class matrices
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28, 3)
# 60000 train samples
# 10000 test samples

# %%
import tensorflow as tf
import mnist
import numpy as np

# Model / data parameters
num_classes = 10
input_shape = (28, 28, 3)

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

# Convert grayscale images to RGB format by replicating the single channel
x_train = np.tile(x_train, (1, 1, 1, 3))
x_test = np.tile(x_test, (1, 1, 1, 3))

print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")

# convert class vectors to binary class matrices
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28, 3)
# 60000 train samples
# 10000 test samples

# %%
import tensorflow as tf
import numpy as np

# Model / data parameters
num_classes = 10
input_shape = (28, 28, 3)

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

# Convert grayscale images to RGB format by replicating the single channel
x_train = np.tile(x_train, (1, 1, 1, 3))
x_test = np.tile(x_test, (1, 1, 1, 3))

print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")

# convert class vectors to binary class matrices
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28, 3)
# 60000 train samples
# 10000 test samples

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
import tensorflow.keras.layers as layers
from tensorflow.keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from tensorflow.keras.callbacks import ReduceLROnPlateau

model = tf.keras.Sequential(
    [
        tf.keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 26, 26, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dropout (Dropout)           (None, 1600)              0
#
#  dense (Dense)               (None, 10)                16010
#
# ...
# Total params: 35402 (138.29 KB)
# Trainable params: 35402 (138.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/2
# 422/422 [==============================] - 47s 105ms/step - loss: 0.1057 - accuracy: 0.9673 - val_loss: 0.0468 - val_accuracy: 0.9875
# Epoch 2/2
# 422/422 [==============================] - 43s 101ms/step - loss: 0.0743 - accuracy: 0.9770 - val_loss: 0.0402 - val_accuracy: 0.9882

# %%
# The probabilites of each class were calculated for each image.
prob_pred = model.predict(x_test)

# The class that has the highest probability will be likeyly the answer.
# Get classes predicted by the model
y_pred = prob_pred.argmax(-1)
# Get true classes
y_true = np.where(y_test == 1)[1]
# Out:
# 313/313 [==============================] - 7s 20ms/step

# %%
classes = [str(i) for i in range(10)]
print(classification_report(y_true, y_pred, target_names = classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       980
#            1       0.99      1.00      0.99      1135
#            2       0.99      0.98      0.99      1032
#            3       0.99      0.99      0.99      1010
#            4       0.98      1.00      0.99       982
#            5       0.99      0.99      0.99       892
#            6       1.00      0.98      0.99       958
#            7       0.98      0.99      0.98      1028
#            8       0.99      0.98      0.98       974
#            9       1.00      0.96      0.98      1009
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import classification_report

# Your classification report data
report_data = classification_report(y_true, y_pred, target_names=classes, output_dict=True)

# Convert the report data to a Pandas DataFrame for easy plotting
report_df = pd.DataFrame(report_data).transpose()

# Define the classes and metrics
classes = report_df.index[:-3]  # Exclude 'accuracy', 'macro avg', and 'weighted avg'
metrics = ['precision', 'recall', 'f1-score']

# Transpose the DataFrame for easy plotting
report_df = report_df[metrics].T

# Create a stacked bar chart
fig, ax = plt.subplots(figsize=(10, 6))

report_df.plot(kind='bar', stacked=True, ax=ax, colormap='coolwarm', alpha=0.8)

plt.xlabel('Metric')
plt.ylabel('Score')
plt.title('Precision, Recall, and F1-Score for Each Class')
plt.xticks(rotation=0)
plt.legend(loc='upper right', title='Class')

# Annotate the bars with values
for bar in ax.containers:
    ax.bar_label(bar, label_type='edge', fontsize=10, padding=3)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import pandas as pd

# Your classification report data
report_data = classification_report(y_true, y_pred, target_names=classes, output_dict=True)

# Extract precision, recall, and f1-score for each class
class_metrics = report_data.keys()
metrics = ['precision', 'recall', 'f1-score']

# Create a Pandas DataFrame for class-wise metrics
class_metrics_df = pd.DataFrame({metric: [report_data[class_label][metric] for class_label in class_metrics if class_label in classes] for metric in metrics}, index=classes)

# Plot line charts for precision, recall, and f1-score
plt.figure(figsize=(12, 6))

for metric in metrics:
    plt.plot(class_metrics_df.index, class_metrics_df[metric], marker='o', label=metric)

plt.xlabel('Class')
plt.ylabel('Score')
plt.title('Precision, Recall, and F1-Score for Each Class')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Make a cofusion matrix between the predictions and the answers
cm = confusion_matrix(y_true, y_pred)

# %%
# Plot confusion matrix for evaluations
plt.figure(figsize = (15,15))
sns.heatmap(cm,cmap= "Blues", linecolor = 'black' , linewidth = 1 , annot = True, fmt='')
# Out:
# <Axes: >

# %%
# Get ID of tests with wrong predictions
id_error_tests = (y_pred - y_true != 0)

# Get the predicted labels for error tests
pred_label_error_tests = y_pred[id_error_tests]
# Get the true labels for error tests
true_label_error_tests = y_true[id_error_tests]
# Get the error tests out of initial tests
error_tests = x_test[id_error_tests]

# Probabilities for all classes in error tests
pred_prob_error_tests = prob_pred[id_error_tests]
# Probabilities for predicted class only in error tests
pred_label_prob_error_tests = np.max(pred_prob_error_tests, axis = 1)
# Probabilities for true class only in error tests
true_label_prob_error_tests = np.diagonal(np.take(pred_prob_error_tests, true_label_error_tests, axis = 1))

# Delta of probabilities between true and predicted labels in error tests
delta_prob_error_tests = pred_label_prob_error_tests - true_label_prob_error_tests
# Get id of 10 error tests with greatest difference in probabilities
id_10_greatest_differences_error_tests = np.argsort(delta_prob_error_tests)[-10:]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have already calculated and defined the variables id_10_greatest_differences_error_tests and delta_prob_error_tests

# Sort the indices of error tests by the delta of probabilities in descending order
sorted_indices = np.argsort(delta_prob_error_tests)[::-1]

# Get the top 10 test case indices with the greatest differences
top_10_indices = sorted_indices[:10]

# Define colors for the bars
colors = ['coral', 'lightblue', 'lightgreen', 'salmon', 'lightseagreen', 'lightcoral', 'lightskyblue', 'lightpink', 'lightgreen', 'lightsalmon']

# Create a figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Create a horizontal bar plot with colorful bars
bars = ax.barh(np.arange(10), delta_prob_error_tests[top_10_indices], color=colors, edgecolor='black')

# Add text labels for each bar
for i, delta in enumerate(delta_prob_error_tests[top_10_indices]):
    ax.text(delta, i, f'{delta:.2f}', va='center', fontsize=10, color='black')

# Customize the appearance
ax.set_yticks(np.arange(10))
ax.set_yticklabels(top_10_indices)
ax.set_xlabel('Delta of Probabilities (Predicted - True)')
ax.set_ylabel('Test Case Index')
ax.set_title('Top 10 Test Cases with Greatest Differences in Probabilities')

# Add a grid
ax.grid(axis='x', linestyle='--', alpha=0.7)

# Add a background color
ax.set_facecolor('whitesmoke')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have already calculated and defined the variable cm (confusion matrix)

# Create a figure and axes
plt.figure(figsize=(10, 8))

# Create a heatmap of the confusion matrix with annotations and a color map
sns.heatmap(cm, cmap="YlGnBu", annot=True, fmt='d', linewidths=1, linecolor='black', cbar=False)

# Set labels and title
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")

# Show the plot
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import precision_recall_curve, average_precision_score

# Assuming you have y_true and y_pred_prob for a binary classification problem
fpr, tpr, _ = roc_curve(y_true, y_pred_prob)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

precision, recall, _ = precision_recall_curve(y_true, y_pred_prob)
average_precision = average_precision_score(y_true, y_pred_prob)
plt.figure()
plt.step(recall, precision, color='b', where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2, color='b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title(f'Precision-Recall curve: AP={average_precision:.2f}')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-8ac4fa844387> in <cell line: 5>()
#       3
#       4 # Assuming you have y_true and y_pred_prob for a binary classification problem
# ----> 5 fpr, tpr, _ = roc_curve(y_true, y_pred_prob)
#       6 roc_auc = auc(fpr, tpr)
#       7 plt.figure()
#
# NameError: name 'y_pred_prob' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set a custom color palette for Seaborn
sns.set_palette("pastel")

plt.figure(figsize=(10, 6))
sns.histplot(delta_prob_error_tests, bins=20, kde=True, color='skyblue', element='step', fill=False, line_kws={"linewidth": 2})
plt.xlabel("Probability Difference (Predicted - True)")
plt.ylabel("Frequency")
plt.title("Distribution of Probability Differences")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
def show_10_error_tests(id, img, pred_labels, true_labels):
    n = 0
    nrows = 2
    ncols = 5

    fig, ax = plt.subplots(nrows, ncols, sharex = True, sharey= True, figsize = (20,8))

    for row in range(nrows):
        for col in range(ncols):
            ax[row, col].imshow(img[id[n]].reshape((28, 28, 3)))
            ax[row, col].set_title("Predicted label: {}\nTrue label: {}".format
                                  (pred_labels[id[n]], true_labels[id[n]]))
            n += 1

    plt.show()

show_10_error_tests(id_10_greatest_differences_error_tests,
                    error_tests,
                    pred_label_error_tests,
                    true_label_error_tests)

# %%
id_10_greatest_differences_error_tests
# Out:
# array([105,  83, 111,  12, 100, 108,  51,  53, 128,  68])

# %%
# !pip install shap

# %%
import shap

# Intializae
explainer = shap.DeepExplainer(model, (x_train[0:1000]))

for id_test in id_10_greatest_differences_error_tests:
    # Get SHap values
    shap_values = explainer.shap_values(error_tests[[id_test]])

    index_names = np.array([str(x) + "\n" + '{:>7.3%}'.format
                            (pred_prob_error_tests[id_test][x]) for x in range(10)]).reshape(1,10)
    print("Predicted label :{}\nTrue label :{}".format
          (pred_label_error_tests[id_test],true_label_error_tests[id_test]))

    # Plot
    shap.image_plot(shap_values, error_tests[[id_test]], index_names, show = False)
    plt.show()
# Out:
# Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
# `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
# ...

# %%
# !pip install aix360
# !pip install lime

# %%
import aix360
from aix360.algorithms.lime import LimeImageExplainer
from skimage.segmentation import mark_boundaries

# intialize explainer
lime_explainer = LimeImageExplainer()

# %%
for i in id_10_greatest_differences_error_tests:

    plt.xticks([])
    plt.yticks([])
    plt.grid(False)

    # Explain.
    explanation = lime_explainer.explain_instance(error_tests[i], model.predict, top_labels=5, hide_color=0, num_samples=3)
    print("Predicted label :{}\nTrue label :{}".format(pred_label_error_tests[i],true_label_error_tests[i]))
    # Plot original
    plt.subplot(1,3,1)
    plt.imshow(error_tests[i])


    # Displays the results.
    temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=10, hide_rest=True)
    plt.subplot(1,3,2)
    plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
    print("Top predictions: " + str(explanation.top_labels))
    temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features=10, hide_rest=True)
    plt.subplot(1,3,3)
    plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

    plt.show()

    # Select the same class explained on the figures above.
    ind =  explanation.top_labels[0]

    # Map each explanation weight to the corresponding superpixel
    dict_heatmap = dict(explanation.local_exp[ind])
    heatmap = np.vectorize(dict_heatmap.get)(explanation.segments)

    #Plot. The visualization makes more sense if a symmetrical colorbar is used.
    plt.imshow(heatmap, cmap = 'RdBu', vmin  = -heatmap.max(), vmax = heatmap.max())
    plt.colorbar()
    plt.show()
# Out:
# ...
# 1/1 [==============================] - 0s 36ms/step
# Predicted label :8
# True label :3
# Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
# Top predictions: [8, 3, 5, 9, 2]
# ...
# 1/1 [==============================] - 0s 32ms/step
# Predicted label :7
# True label :2
# Top predictions: [7, 2, 4, 8, 3]
# Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
# ...
# 1/1 [==============================] - 0s 33ms/step
# Predicted label :7
# True label :0
# Top predictions: [7, 9, 0, 3, 2]
# Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
# ...
# 1/1 [==============================] - 0s 37ms/step
# Predicted label :5
# True label :6
# Top predictions: [5, 6, 9, 0, 3]
# ...

# %%
from aix360.algorithms.lime import LimeImageExplainer
from skimage.segmentation import mark_boundaries

# Initialize LIME explainer
lime_explainer = LimeImageExplainer()

# Explain an individual test case
explanation = lime_explainer.explain_instance(error_tests[id_test], model.predict, top_labels=5, hide_color=0, num_samples=3)

# Plot the original image
plt.subplot(1, 3, 1)
plt.imshow(error_tests[id_test])

# Display results
temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=10, hide_rest=True)
plt.subplot(1, 3, 2)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
print("Top predictions: " + str(explanation.top_labels))

# Map each explanation weight to the corresponding superpixel
dict_heatmap = dict(explanation.local_exp[ind])
heatmap = np.vectorize(dict_heatmap.get)(explanation.segments)

# Plot the heatmap
plt.imshow(heatmap, cmap='RdBu', vmin=-heatmap.max(), vmax=heatmap.max())
plt.colorbar()
plt.show()
# Out:
# ...
# 1/1 [==============================] - 0s 36ms/step
# Top predictions: [8, 3, 5, 9, 2]

# %%
from aix360.algorithms.lime import LimeImageExplainer
from skimage.segmentation import mark_boundaries

# Initialize LIME explainer
lime_explainer = LimeImageExplainer()

for i in id_10_greatest_differences_error_tests:
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)

    # Explain.
    explanation = lime_explainer.explain_instance(error_tests[i], model.predict, top_labels=5, hide_color=0, num_samples=3)
    print("Predicted label :{}\nTrue label :{}".format(pred_label_error_tests[i], true_label_error_tests[i]))

    # Plot original
    plt.subplot(1, 3, 1)
    plt.imshow(error_tests[i])

    # Display results.
    temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=10, hide_rest=True)
    plt.subplot(1, 3, 2)
    plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
    print("Top predictions: " + str(explanation.top_labels))

    temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features=10, hide_rest=True)
    plt.subplot(1, 3, 3)
    plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

    plt.show()

    # Select the same class explained on the figures above.
    ind = explanation.top_labels[0]

    # Map each explanation weight to the corresponding superpixel
    dict_heatmap = dict(explanation.local_exp[ind])
    heatmap = np.vectorize(dict_heatmap.get)(explanation.segments)

    # Plot. The visualization makes more sense if a symmetrical colorbar is used.
    plt.imshow(heatmap, cmap='RdBu', vmin=-heatmap.max(), vmax=heatmap.max())
    plt.colorbar()
    plt.show()
# Out:
# ...
# 1/1 [==============================] - 0s 34ms/step
# Predicted label :8
# True label :3
# Top predictions: [8, 3, 5, 9, 2]
# Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
# ...
# 1/1 [==============================] - 0s 37ms/step
# Predicted label :7
# True label :2
# Top predictions: [7, 2, 4, 8, 3]
# Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
# ...
# 1/1 [==============================] - 0s 39ms/step
# Predicted label :7
# True label :0
# Top predictions: [7, 9, 0, 3, 2]
# Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
# ...
# 1/1 [==============================] - 0s 33ms/step
# Predicted label :5
# True label :6
# Top predictions: [5, 6, 9, 0, 3]
# ...

# %%
count = 0
for num in range(0,x_test.shape[0]) :
    if id_error_tests[num] == False:
        # ----------------------SHAP explains--------------------
        count += 1
        # Calculates the SHAP value.
        shap_values = explainer.shap_values(x_test[[num]])

        # Labels
        index_names = np.array([str(x) + "\n" + '{:>7.3%}'.format(prob_pred[num][x]) for x in range(10)]).reshape(1,10)
        print("Predicted label :{}\nTrue label :{}".format(y_pred[num],np.argmax(y_test[num])))

        # Displays the results.
        shap.image_plot(shap_values, x_test[[num]] ,index_names ,show=False)
        plt.show()

        # ---------------------LIMEs explains-------------------

        plt.xticks([])
        plt.yticks([])
        plt.grid(False)

        # Explain.
        explanation = lime_explainer.explain_instance(x_test[num], model.predict, top_labels=5, hide_color=0, num_samples=3)
        # Plot original
        plt.subplot(1,3,1)
        plt.imshow(x_test[num])


        # Displays the results.
        temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=10, hide_rest=True)
        plt.subplot(1,3,2)
        plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
        print("Top predictions: " + str(explanation.top_labels))
        temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features=10, hide_rest=True)
        plt.subplot(1,3,3)
        plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

        plt.show()

        # Select the same class explained on the figures above.
        ind =  explanation.top_labels[0]

        # Map each explanation weight to the corresponding superpixel
        dict_heatmap = dict(explanation.local_exp[ind])
        heatmap = np.vectorize(dict_heatmap.get)(explanation.segments)

        #Plot. The visualization makes more sense if a symmetrical colorbar is used.
        plt.imshow(heatmap, cmap = 'RdBu', vmin  = -heatmap.max(), vmax = heatmap.max())
        plt.colorbar()
        plt.show()

        if count >= 2:
          break
# Out:
# Predicted label :7
# True label :7
# ...
# 1/1 [==============================] - 0s 39ms/step
# Top predictions: [7, 3, 2, 9, 8]
# Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
# Predicted label :2
# True label :2
# ...
# 1/1 [==============================] - 0s 43ms/step
# Top predictions: [2, 1, 0, 6, 8]
# Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.

# %%
import shap
import matplotlib.pyplot as plt
from aix360.algorithms.lime import LimeImageExplainer
from skimage.segmentation import mark_boundaries

# Initialize the LIME explainer
lime_explainer = LimeImageExplainer()

# Variables to track the number of analyzed instances
shap_count = 0
lime_count = 0

for num in range(x_test.shape[0]):
    if id_error_tests[num] == False:
        # ---------------------- SHAP explains --------------------
        shap_count += 1
        shap_values = explainer.shap_values(x_test[[num]])

        print("SHAP - Predicted label: {}\nTrue label: {}".format(y_pred[num], np.argmax(y_test[num]))

        # Displays the results.
        shap.image_plot(shap_values, x_test[[num]], show=True)

        if shap_count >= 2:
            break

        # --------------------- LIME explains -------------------
        lime_count += 1

        # Explain using LIME
        explanation = lime_explainer.explain_instance(x_test[num], model.predict, top_labels=5, hide_color=0, num_samples=3)

        # Display LIME explanations
        temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=10, hide_rest=True)
        plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
        plt.show()

        if lime_count >= 2:
            break

# Continue with additional analysis and visualization as needed
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/compilerop.py in ast_parse(self, source, filename, symbol)
#      99         Arguments are exactly the same as ast.parse (in the standard library),
#     100         and are passed to the built-in compile function."""
# --> 101         return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#     102
#     103     def reset_compiler_flags(self):
#
# SyntaxError: '(' was never closed (<ipython-input-51-781b0adfbf66>, line 19)
